# %%
import pandas as pd

# %%
data=pd.read_csv('weather.csv',index_col="DATE")

# %%
data.head()
# Out:
#                 STATION                              NAME  ACMH   ACSH  AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0   NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0   NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0   NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0   NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0   NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   NaN   1.0
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...

# %%
#cleaning the data

# %%
null_pct=data.apply(pd.isnull).sum()/data.shape[0]#(no of rows)calculting the % of null values in each row

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
#cleaning the data where the null percentage is value is low

# %%
valid_columns=data.columns[null_pct < 0.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
data=data[valid_columns].copy()

# %%
data.head()
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             TMAX  TMIN
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21

# %%
#lowercasing the column names

# %%
data.columns=data.columns.str.lower()

# %%
data.head()
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21

# %%
data.isnull().sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       2
# tmax       0
# tmin       0
# dtype: int64

# %%
data=data.ffill()#filling null value by the last non_missing value

# %%
data.isnull().sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
#checking for the datatypes

# %%
data.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
#checking the index

# %%
data.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
#here index is stored as object but its actually a date

# %%
#converting the index to datetime
data.index=pd.to_datetime(data.index)

# %%
data.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15',
#                '2022-10-16', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='DATE', length=19287, freq=None)

# %%
data.index.year
# Out:
# Int64Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#             ...
#             2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='DATE', length=19287)

# %%
data.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: DATE, dtype: int64

# %%
data['snwd'].plot()#to show snow depth by day
# Out:
# <Axes: xlabel='DATE'>

# %%
#problem statement we are trying to predict the next days weather temperature

# %%
data['target']=data.shift(-1)['tmax']

# %%
data.tail()
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43     NaN

# %%
data=data.ffill()

# %%
data.tail()
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43    64.0

# %%
from sklearn.linear_model import Ridge

# %%
data.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17356\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.151051  0.001178 -0.007210  0.052279 -0.003358
# snow    0.151051  1.000000  0.232567 -0.175075 -0.159285 -0.172737
# snwd    0.001178  0.232567  1.000000 -0.259858 -0.256977 -0.241054
# tmax   -0.007210 -0.175075 -0.259858  1.000000  0.955487  0.915296
# tmin    0.052279 -0.159285 -0.256977  0.955487  1.000000  0.915461
# target -0.003358 -0.172737 -0.241054  0.915296  0.915461  1.000000

# %%
rr=Ridge(alpha=.1)

# %%
predictors=data.columns[~data.columns.isin(['target','name','station'])]#fetch all the columns except(target,name,station)

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
#since this is a time series data we are going to do a backtest or cross_validation with time

# %%
def backtest(data,model,predictors,start=3650,step=90):
    all_predictions=[]
    
    for i in range(start,data.shape[0],step):
        train=data.iloc[:i,:]
        test=data.iloc[i:(i+step),:]
        model.fit(train[predictors],train['target'])
        
        preds=model.predict(test[predictors])
        
        preds=pd.Series(preds,index=test.index)
        
        combined=pd.concat([test['target'],preds],axis=1)
        
        combined.columns=['actual','prediction']
        
        combined['diff']=(combined['prediction']-combined['actual']).abs()
        all_predictions.append(combined)
        
        return pd.concat(all_predictions)

# %%
predictions=backtest(data,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 1980-03-24    42.0   48.720456   6.720456
# 1980-03-25    49.0   45.778115   3.221885
# 1980-03-26    53.0   50.644952   2.355048
# 1980-03-27    51.0   52.307466   1.307466
# 1980-03-28    52.0   51.476209   0.523791
#
# [90 rows x 3 columns]

# %%
#to evaluate performance we use mean absolute error

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(predictions['actual'],predictions['prediction'])
# Out:
# 4.8922399991294885

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.430619  21.569381
# 1980-02-28    22.0   37.440442  15.440442
# 1980-01-23    25.0   40.107146  15.107146
# 1980-02-20    56.0   40.922191  15.077809
# 1980-03-16    53.0   41.685701  11.314299
# ...            ...         ...        ...
# 1980-02-17    32.0   31.788391   0.211609
# 1980-01-17    41.0   40.865606   0.134394
# 1980-02-09    35.0   34.877467   0.122533
# 1980-01-22    42.0   41.892845   0.107155
# 1980-03-20    49.0   48.961722   0.038278
#
# [90 rows x 3 columns]

# %%
#imporving the accuracy

# %%
def pct_diff(old,new):
    return (new-old)/old

def compute_rolling(data,horizon,col):
    label=f"rolling_{horizon}_{col}"
    
    data[label]=data[col].rolling(horizon).mean()
    
    data[f"{label}_pct"]= pct_diff(data[label],data[col])
    
    return data
rolling_horizons=[3,14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        data= compute_rolling(data, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    data[f"month_avg_{col}"] = data[col].groupby(data.index.month, group_keys=False).apply(expand_mean)
    data[f"day_avg_{col}"] = data[col].groupby(data.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
data=data.iloc[14:,:]
data=data.fillna(0)

# %%
predictors = data.columns[~data.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# station                0
# name                   0
# prcp                   0
# snow                   0
# snwd                   0
# tmax                   0
# tmin                   0
# target                 0
# rolling_3_tmax         0
# rolling_3_tmax_pct     0
# rolling_3_tmin         0
# rolling_3_tmin_pct     0
# rolling_3_prcp         0
# rolling_3_prcp_pct     0
# rolling_14_tmax        0
# rolling_14_tmax_pct    0
# rolling_14_tmin        0
# rolling_14_tmin_pct    0
# rolling_14_prcp        0
# rolling_14_prcp_pct    0
# month_avg_tmax         0
# day_avg_tmax           0
# month_avg_tmin         0
# day_avg_tmin           0
# month_avg_prcp         0
# day_avg_prcp           0
# dtype: int64

# %%
predictions = backtest(data, rr, predictors)
mean_absolute_error(predictions['actual'],predictions['prediction'])
# Out:
# 4.29250397328263

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.430619  21.569381
# 1980-02-28    22.0   37.440442  15.440442
# 1980-01-23    25.0   40.107146  15.107146
# 1980-02-20    56.0   40.922191  15.077809
# 1980-03-16    53.0   41.685701  11.314299
# ...            ...         ...        ...
# 1980-02-17    32.0   31.788391   0.211609
# 1980-01-17    41.0   40.865606   0.134394
# 1980-02-09    35.0   34.877467   0.122533
# 1980-01-22    42.0   41.892845   0.107155
# 1980-03-20    49.0   48.961722   0.038278
#
# [90 rows x 3 columns]

# %%
data.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
# ...

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: >

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.430619  21.569381
# 1980-01-14    51.0   44.600179   6.399821
# 1980-01-15    45.0   46.846655   1.846655
# 1980-01-16    40.0   42.211921   2.211921
# 1980-01-17    41.0   40.865606   0.134394
# ...            ...         ...        ...
# 1980-04-07    57.0   56.766407   0.233593
# 1980-04-08    55.0   57.956172   2.956172
# 1980-04-09    63.0   56.643532   6.356468
# 1980-04-10    62.0   59.143359   2.856641
# 1980-04-11    57.0   60.217711   3.217711
#
# [90 rows x 3 columns]
